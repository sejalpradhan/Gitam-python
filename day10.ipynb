# %% [markdown]
# ### 1.Standard Libraries
# - File I/O
# - Regular expression
# - Datetime
# - Math (Numerical and Mathematical)
#
# ### 2.File Handling in Python
# - File:-Document containing information reaches on the permanent storage
# - Different types of files:txt.doc,pdg,csv and ets...
# - Input-- Keyboard
# - Output-- File
#
# ### 3.Modes of the File I/O
# - 'w'-- This Mode id used for File Writing
#  - if the file is not present it creates a file and then writes the data to it

# %%
# Function to create a file and write it to the file
def createFile(filename):
    f = open(filename,'w')
    for i in range(10):
        f.write('This is %d Line\n' % i)
    print("File is created and data has written")
    return
createFile('file1.txt')
# Out:
# File is created and data has written

# %%
def createfile(filename):
    f=open(filename,'w')
    f.write('Testing---\n')
    print("File is created and data has written")
    return
createfile('file2.txt')
# Out:
# File is created and data has written

# %%
#Function to read the file

def fileOperation(filename,mode):
    with open(filename,mode) as f:
        if f.mode == 'r':
            data = f.read()
            print(data)
        elif f.mode == 'a':
            f.write('Data to the file')
            print('The data successfully written')
    f.close()
    returndef filw
filename = input('enter the file name')
mode= input('Enter the mode of the file')
fileOperation(filename,mode)
# Out:
# enter the file namefile1.txt
# Enter the mode of the filer
# This is 0 Line
# This is 1 Line
# This is 2 Line
# This is 3 Line
# This is 4 Line
# This is 5 Line
# This is 6 Line
# This is 7 Line
# This is 8 Line
# This is 9 Line

# %%
# Data Analysis
# Word Count Program
def wordCount(filename,word):
    with open(filename,'r') as f:
        if f.mode == 'r' :
            x = f.read()
            li = x.split() # It's splits the string with
    cnt = li.count(word)
    return cnt
filename = input('Enter the file name : ')
word = input('Enter the word : ') # which word count you
wordCount(filename,word)
# Out:
# Enter the file name : file1.txt
# Enter the word : This
# 10

# %%
#Character count from the given file
def charCount(filename):
    with open(filename,'r') as f:
        if f.mode == 'r':
            x= f.read()
            li= list(x)
    return len(li)
filename = input ("Enter the filename:")
charCount(filename)
# Out:
# Enter the filename:file1.txt
# 150

# %%
#Function to find the no of lines in the input file
#Input -- filename(file2.txt)
#Output -- No. of lines(12)

def countOfLines(filename):
    with open(filename,'r') as f:
        if f.mode =='r':
            x = f.read()
            li = x.split("\n")
    return len(li)
filename = input('Enter the filename:')
countOfLines(filename)
# Out:
# Enter the filename:file1.txt
# 11

# %%
# Function to print upper and lower case characteristics
def caseCount(filename):
    cntUpper = 0
    cntLower = 0
    with open(filename,'r') as f:
        if f.mode == 'r' :
            x = f.read()
            li = list(x)
    for i in li:
        if i.isupper():
            cntUpper += 1 # cntUpper = cntUpper + 1
        elif i.islower():
            cntLower += 1 # cntLower = cntLower + 1
    output = 'Upper case = {0} , Lower case = {1}'.format(cntUpper,cntLower)
    return output
filename = input('Enter the filename : ')
caseCount(filename)
shell
# Out:
# Enter the filename : file2.txt
# 'Upper case = 1 , Lower case = 6'

# %%
cd **
# Out:
# [Errno 2] No such file or directory: '**'
# /home/student/anaconda3

# %%
cd --
# Out:
# /home/student/anaconda3

# %%
import os
os.listdir() # listdir() -- ls
# Out:
# ['var',
#  'day9.ipynb',
#  'libexec',
#  'plugins',
#  'man',
#  'share',
#  'pkgs',
#  'Untitled6.ipynb',
#  'data.txt',
#  'shell',
#  'conda-meta',
#  'LICENSE.txt',
#  'qml',
#  '.ipynb_checkpoints',
#  'resources',
#  'day10.ipynb',
#  'Untitled7.ipynb',
#  'condabin',
#  'file1.txt',
#  'doc',
#  'etc',
#  'sbin',
#  'day9a.ipynb',
#  'x86_64-conda_cos6-linux-gnu',
#  'day6.ipynb',
#  'bin',
#  'day7.ipynb',
#  'file2.txt',
#  'envs',
#  'day8.ipynb',
#  'compiler_compat',
#  'mkspecs',
#  'phrasebooks',
#  'Untitled1.ipynb',
#  'day5.ipynb',
#  'translations',
#  'ssl',
#  'include',
#  'lib']

# %%
import os
os.listdir() # listdir('var/') -- ls
# Out:
# ['var',
#  'day9.ipynb',
#  'libexec',
#  'plugins',
#  'man',
#  'share',
#  'pkgs',
#  'Untitled6.ipynb',
#  'data.txt',
#  'shell',
#  'conda-meta',
#  'LICENSE.txt',
#  'qml',
#  '.ipynb_checkpoints',
#  'resources',
#  'day10.ipynb',
#  'Untitled7.ipynb',
#  'condabin',
#  'file1.txt',
#  'doc',
#  'etc',
#  'sbin',
#  'day9a.ipynb',
#  'x86_64-conda_cos6-linux-gnu',
#  'day6.ipynb',
#  'bin',
#  'day7.ipynb',
#  'file2.txt',
#  'envs',
#  'day8.ipynb',
#  'compiler_compat',
#  'mkspecs',
#  'phrasebooks',
#  'Untitled1.ipynb',
#  'day5.ipynb',
#  'translations',
#  'ssl',
#  'include',
#  'lib']

# %%
li = os.listdir('lib/')
for i in li:
    print (i)
# Out:
# libQt53DCore.prl
# libxcb-sync.a
# libQt53DQuickRender.so
# libkrad.so
# libQt5ScriptTools.so.5.9
# libQt5Qml.so
# libharfbuzz-icu.a
# libQt5SerialBus.so.5.9
# libQt5WebChannel.prl
# libQt53DQuickRender.so.5.9.7
# libpixman-1.so.0
# libgstcheck-1.0.so
# libicui18n.so
# libjpeg.so
# libgsttag-1.0.so.0
# libicui18n.a
# libhdf5.so.103
# libffi.so.6
# libxcb-dri2.so.0.0.0
# libfreetype.so
# libQt5EglSupport.prl
# libxcb-randr.so.0.1.0
# libQt5Svg.so.5
# libQt5InputSupport.a
# libQt5SerialBus.so.5.9.7
# libQt5QuickTest.prl
# libQt53DQuickExtras.so.5.9
# libmpc.la
# libQt5InputSupport.prl
# libtinfo.so.6
# libtiff.a
# libformw.a
# libgstreamer-1.0.so.0
# libQt5DataVisualization.so.5.9
# libQt5WebEngineWidgets.so.5
# libxcb-record.so
# libgstaudio-1.0.so.0
# libQt5OpenGL.prl
# libxcb-dri3.so
# libQt5EglFSDeviceIntegration.so.5
# libQt5WebView.so.5
# libQt53DExtras.so.5
# libiompstubs5.so
# libQt5QuickParticles.so.5.9.7
# libxslt.so
# libxcb-shm.so.0.0.0
# libQt5RemoteObjects.so.5.9.7
# ...

# %%
import os
dirpath = 'resources'
for i in os.listdir(dirpath):
    if os.Path.isfile(os,path,join(dirpath,i)):
        print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-42de335f4b6e> in <module>
#       2 dirpath = 'resources'
#       3 for i in os.listdir(dirpath):
# ----> 4     if os.Path.isfile(os,path,join(dirpath,i)):
#       5         print(i)
#       6
#
# AttributeError: module 'os' has no attribute 'Path'

# %% [markdown]
# ### Listing Subdirectories

# %%
pwd
# Out:
# '/home/student/anaconda3'

# %%
ls
# Out:
# bin/              day9a.ipynb  LICENSE.txt   shell/
# compiler_compat/  day9.ipynb   man/          ssl/
# condabin/         doc/         mkspecs/      translations/
# conda-meta/       envs/        phrasebooks/  Untitled1.ipynb
# data.txt          etc/         pkgs/         Untitled6.ipynb
# day10.ipynb       file1.txt    plugins/      Untitled7.ipynb
# day5.ipynb        file2.txt    qml/          var/
# day6.ipynb        include/     resources/    x86_64-conda_cos6-linux-gnu/
# day7.ipynb        lib/         sbin/
# day8.ipynb        libexec/     share/

# %% [markdown]
# ## Creating Multiple Directories

# %%
import os
os.makedirs('2019/july/11')

# %%
ls
# Out:
# 2019/             day8.ipynb   libexec/      share/
# bin/              day9a.ipynb  LICENSE.txt   shell/
# compiler_compat/  day9.ipynb   man/          ssl/
# condabin/         doc/         mkspecs/      translations/
# conda-meta/       envs/        phrasebooks/  Untitled1.ipynb
# data.txt          etc/         pkgs/         Untitled6.ipynb
# day10.ipynb       file1.txt    plugins/      Untitled7.ipynb
# day5.ipynb        file2.txt    qml/          var/
# day6.ipynb        include/     resources/    x86_64-conda_cos6-linux-gnu/
# day7.ipynb        lib/         sbin/

# %% [markdown]
# ###  Filename pattern matching
